# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Read the dataset

# %%
df =pd.read_csv("udemy_courses.csv")

# %% [markdown]
# ### get some informations about dataset

# %%
df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# 1             2792          923           274          All Levels
# 2             2174           74            51  Intermediate Level
# 3             2451           11            36          All Levels
# 4             1276           45            26  Intermediate Level
#
#    content_duration   published_timestamp           subject
# 0               1.5  2017-01-18T20:58:58Z  Business Finance
# 1              39.0  2017-03-09T16:34:20Z  Business Finance
# 2               2.5  2016-12-19T19:26:30Z  Business Finance
# 3               3.0  2017-05-30T20:07:24Z  Business Finance
# 4               2.0  2016-12-13T14:57:18Z  Business Finance

# %%
df.sample(5)
# Out:
#       course_id                                       course_title  \
# 3063     783158                          Getting Started with HTML
# 2059     638100  Fingerstyle Guitar by Jacques Stotzem - Advanc...
# 257      833770             Practical Financial Statement Analysis
# 621      688244       How I Make Money Writing About Stocks Online
# 2603     751100       Scrape Websites using PhantomJS and CasperJS
#
#                                                     url  is_paid  price  \
# 3063          https://www.udemy.com/html-basics-course/     True     40
# 2059  https://www.udemy.com/fingerstyleguitar-jacque...     True     30
# 257   https://www.udemy.com/practical-financial-stat...     True     75
# 621   https://www.udemy.com/seeking-alpha-how-to-wri...     True    195
# 2603  https://www.udemy.com/scrape-websites-phantomj...     True    195
#
#       num_subscribers  num_reviews  num_lectures               level  \
# 3063             7375           52            17      Beginner Level
# 2059               77            4            14          All Levels
# 257                22            5            45          All Levels
# 621               360           24            12      Beginner Level
# 2603              960          110            32  Intermediate Level
#
#       content_duration   published_timestamp              subject
# 3063               1.5  2016-03-07T18:40:52Z      Web Development
# 2059               2.0  2015-10-13T20:36:14Z  Musical Instruments
# 257                4.5  2017-05-01T23:22:07Z     Business Finance
# 621                2.5  2015-12-18T02:55:11Z     Business Finance
# 2603               2.0  2016-02-26T18:21:13Z      Web Development

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   object
#  11  subject              3678 non-null   object
# dtypes: bool(1), float64(1), int64(5), object(5)
# memory usage: 319.8+ KB

# %% [markdown]
# #### ----> there is no null data in every column

# %%
df.describe()
# Out:
#           course_id        price  num_subscribers   num_reviews  num_lectures  \
# count  3.678000e+03  3678.000000      3678.000000   3678.000000   3678.000000
# mean   6.759720e+05    66.049483      3197.150625    156.259108     40.108755
# std    3.432732e+05    61.005755      9504.117010    935.452044     50.383346
# min    8.324000e+03     0.000000         0.000000      0.000000      0.000000
# 25%    4.076925e+05    20.000000       111.000000      4.000000     15.000000
# 50%    6.879170e+05    45.000000       911.500000     18.000000     25.000000
# 75%    9.613555e+05    95.000000      2546.000000     67.000000     45.750000
# max    1.282064e+06   200.000000    268923.000000  27445.000000    779.000000
#
#        content_duration
# count       3678.000000
# mean           4.094517
# std            6.053840
# min            0.000000
# 25%            1.000000
# 50%            2.000000
# 75%            4.500000
# max           78.500000

# %% [markdown]
# ## date cleaning

# %% [markdown]
# ### - null data :

# %%
df.isnull().sum()
# Out:
# course_id              0
# course_title           0
# url                    0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %% [markdown]
# ### ---> there is no null data

# %% [markdown]
# ## - delete unnecessary columns :

# %%
df.drop('course_id',axis=1,inplace=True)

# %%
df.drop('url',axis=1,inplace=True)

# %%
df.head()
# Out:
#                                         course_title  is_paid  price  \
# 0                 Ultimate Investment Banking Course     True    200
# 1  Complete GST Course & Certification - Grow You...     True     75
# 2  Financial Modeling for Business Analysts and C...     True     45
# 3  Beginner to Pro - Financial Analysis in Excel ...     True     95
# 4       How To Maximize Your Profits Trading Options     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# 1             2792          923           274          All Levels
# 2             2174           74            51  Intermediate Level
# 3             2451           11            36          All Levels
# 4             1276           45            26  Intermediate Level
#
#    content_duration   published_timestamp           subject
# 0               1.5  2017-01-18T20:58:58Z  Business Finance
# 1              39.0  2017-03-09T16:34:20Z  Business Finance
# 2               2.5  2016-12-19T19:26:30Z  Business Finance
# 3               3.0  2017-05-30T20:07:24Z  Business Finance
# 4               2.0  2016-12-13T14:57:18Z  Business Finance

# %% [markdown]
# ### unnecessary column removed

# %% [markdown]
# ## validate columns data types

# %%
df['published_timestamp']=pd.to_datetime(df['published_timestamp'])

# %%
df.head()
# Out:
#                                         course_title  is_paid  price  \
# 0                 Ultimate Investment Banking Course     True    200
# 1  Complete GST Course & Certification - Grow You...     True     75
# 2  Financial Modeling for Business Analysts and C...     True     45
# 3  Beginner to Pro - Financial Analysis in Excel ...     True     95
# 4       How To Maximize Your Profits Trading Options     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# 1             2792          923           274          All Levels
# 2             2174           74            51  Intermediate Level
# 3             2451           11            36          All Levels
# 4             1276           45            26  Intermediate Level
#
#    content_duration       published_timestamp           subject
# 0               1.5 2017-01-18 20:58:58+00:00  Business Finance
# 1              39.0 2017-03-09 16:34:20+00:00  Business Finance
# 2               2.5 2016-12-19 19:26:30+00:00  Business Finance
# 3               3.0 2017-05-30 20:07:24+00:00  Business Finance
# 4               2.0 2016-12-13 14:57:18+00:00  Business Finance

# %% [markdown]
# ### ---> all data types is valid

# %% [markdown]
# ## Remove duplicated rows

# %%
#showdu plicates
df[df.duplicated()]
# Out:
#                                            course_title  is_paid  price  \
# 787   Essentials of money value: Get a financial Life !     True     20
# 788   Introduction to Forex Trading Business For Beg...     True     20
# 894                  Understanding Financial Statements     True     25
# 1100                  CFA Level 2- Quantitative Methods     True     40
# 1473                             MicroStation - Células     True     20
# 2561  Learn Web Designing & HTML5/CSS3 Essentials in...     True     75
#
#       num_subscribers  num_reviews  num_lectures           level  \
# 787                 0            0            20      All Levels
# 788                 0            0            27  Beginner Level
# 894                 0            0            10      All Levels
# 1100                0            0            35      All Levels
# 1473                0            0             9  Beginner Level
# 2561            43285          525            24      All Levels
#
#       content_duration       published_timestamp           subject
# 787           0.616667 2016-05-16 18:28:30+00:00  Business Finance
# 788           1.500000 2017-04-23 16:19:01+00:00  Business Finance
# 894           1.000000 2016-12-15 14:56:17+00:00  Business Finance
# 1100          5.500000 2017-07-02 14:29:35+00:00  Business Finance
# 1473          0.616667 2014-04-15 21:48:55+00:00    Graphic Design
# 2561          4.000000 2013-01-03 00:55:31+00:00   Web Development

# %%
#remove duplicates
df.drop_duplicates(inplace=True)

# %% [markdown]
# ## visualize data and get conclusions

# %%
plt.title("paid courses and free courses")
sns.countplot('is_paid',data=df)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'paid courses and free courses'}, xlabel='is_paid', ylabel='count'>

# %%
df['is_paid'].value_counts()
# Out:
# True     3362
# False     310
# Name: is_paid, dtype: int64

# %% [markdown]
# ### -->most cources is paid

# %%
plt.title(" courses subjects")
sns.countplot('subject',data=df)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':' courses subjects'}, xlabel='subject', ylabel='count'>

# %%
df['subject'].value_counts()
# Out:
# Web Development        1199
# Business Finance       1191
# Musical Instruments     680
# Graphic Design          602
# Name: subject, dtype: int64

# %% [markdown]
# ### --> web devolopment and Business Finance is the most common cources

# %%
plt.title("courses levels")
sns.countplot('level',data=df)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'courses levels'}, xlabel='level', ylabel='count'>

# %% [markdown]
# ### --> most cources is in (all levels)

# %% [markdown]
# -------
# ## Relation between price and number of subscribers

# %%
plt.title('price vs num_subscribers')
sns.regplot(x='price',y='num_subscribers',data=df)
# Out:
# <AxesSubplot:title={'center':'price vs num_subscribers'}, xlabel='price', ylabel='num_subscribers'>

# %% [markdown]
# ### --> there is no relation between the price and number of subscribers

# %% [markdown]
# -------
# ## Relation between price and content duration

# %%
plt.title('price vs content_duration')
sns.regplot(x='price',y='content_duration',data=df)
# Out:
# <AxesSubplot:title={'center':'price vs content_duration'}, xlabel='price', ylabel='content_duration'>

# %% [markdown]
# ### --> price increased by increasing of content duration

# %% [markdown]
# -------
# ## Relation between content duration and number if subscribers

# %%
plt.title('content_duration vs num_subscribers')
sns.regplot(x='content_duration',y='num_subscribers',data=df)
# Out:
# <AxesSubplot:title={'center':'content_duration vs num_subscribers'}, xlabel='content_duration', ylabel='num_subscribers'>

# %% [markdown]
# ### --> there is more number of subscribers by increasing content duration

# %% [markdown]
# -------
# ## Relation between content duration and number of reviews

# %%
plt.title('content_duration vs num_reviews')
sns.regplot(x='content_duration',y='num_reviews',data=df)
# Out:
# <AxesSubplot:title={'center':'content_duration vs num_reviews'}, xlabel='content_duration', ylabel='num_reviews'>

# %% [markdown]
# ### --> there is more number of reviews by increasing content duration
